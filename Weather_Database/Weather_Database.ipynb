# %%
from citipy import citipy
import pandas as pd
import numpy as np
from config import weather_api_key
import requests
import time
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 747

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e422f1b46ff65ddd19a2a1fe9686417c

# %%
# Retrieve the following information from the API call:
    # Latitude and longitude
    # Maximum temperature
    # Percent humidity
    # Percent cloudiness
    # Wind speed
    # Weather description (for example, clouds, fog, light rain, clear sky)
    
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):

    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    city_url = url + "&q=" + city.replace(" ","+")

    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    record_count += 1
    
    try:
       
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_weat_desc = city_weather["weather"][0]["description"]
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather description": city_weat_desc})

    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gurgan
# City not found. Skipping...
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | ca mau
# Processing Record 4 of Set 1 | katsuura
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | san cristobal
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | karratha
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | tabou
# Processing Record 12 of Set 1 | georgetown
# Processing Record 13 of Set 1 | victoria
# Processing Record 14 of Set 1 | nuuk
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | gat
# Processing Record 17 of Set 1 | port-cartier
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | concepcion del oro
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | asyut
# Processing Record 24 of Set 1 | kasongo
# Processing Record 25 of Set 1 | tateyama
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | rundu
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | sal rei
# Processing Record 31 of Set 1 | vrangel
# Processing Record 32 of Set 1 | roma
# Processing Record 33 of Set 1 | ancud
# Processing Record 34 of Set 1 | beringovskiy
# Processing Record 35 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | kawalu
# Processing Record 39 of Set 1 | severo-kurilsk
# Processing Record 40 of Set 1 | kincardine
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | sao sebastiao
# Processing Record 47 of Set 1 | leningradskiy
# Processing Record 48 of Set 1 | ypsonas
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | ormond beach
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | gdynia
# Processing Record 4 of Set 2 | ndele
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | arman
# Processing Record 7 of Set 2 | rakoshyno
# Processing Record 8 of Set 2 | pangnirtung
# Processing Record 9 of Set 2 | harsin
# Processing Record 10 of Set 2 | barcelos
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | kavaratti
# Processing Record 14 of Set 2 | walvis bay
# Processing Record 15 of Set 2 | ardahan
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | codrington
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | saint-pierre
# Processing Record 20 of Set 2 | bacon
# Processing Record 21 of Set 2 | bambous virieux
# Processing Record 22 of Set 2 | salinas
# Processing Record 23 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 2 | buraydah
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | yulara
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | huron
# Processing Record 29 of Set 2 | ilulissat
# Processing Record 30 of Set 2 | kalmunai
# Processing Record 31 of Set 2 | robertsport
# Processing Record 32 of Set 2 | mar del plata
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | krasnoarmeysk
# Processing Record 35 of Set 2 | longkou
# Processing Record 36 of Set 2 | sinnamary
# Processing Record 37 of Set 2 | san quintin
# Processing Record 38 of Set 2 | cherskiy
# Processing Record 39 of Set 2 | tessalit
# Processing Record 40 of Set 2 | vila velha
# Processing Record 41 of Set 2 | ribeira grande
# Processing Record 42 of Set 2 | yertsevo
# Processing Record 43 of Set 2 | talnakh
# Processing Record 44 of Set 2 | sept-iles
# Processing Record 45 of Set 2 | comodoro rivadavia
# Processing Record 46 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | axim
# Processing Record 49 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 2 | qaanaaq
# Processing Record 1 of Set 3 | minab
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | fortuna
# Processing Record 4 of Set 3 | castro
# Processing Record 5 of Set 3 | rocha
# Processing Record 6 of Set 3 | asau
# Processing Record 7 of Set 3 | khuzdar
# Processing Record 8 of Set 3 | danville
# Processing Record 9 of Set 3 | te anau
# Processing Record 10 of Set 3 | muros
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | coihaique
# Processing Record 13 of Set 3 | west wendover
# Processing Record 14 of Set 3 | havelock
# Processing Record 15 of Set 3 | griffith
# Processing Record 16 of Set 3 | springbok
# Processing Record 17 of Set 3 | beitbridge
# Processing Record 18 of Set 3 | sitka
# Processing Record 19 of Set 3 | altay
# Processing Record 20 of Set 3 | hovd
# Processing Record 21 of Set 3 | bathsheba
# Processing Record 22 of Set 3 | carballo
# Processing Record 23 of Set 3 | hilo
# Processing Record 24 of Set 3 | tuktoyaktuk
# Processing Record 25 of Set 3 | srednekolymsk
# Processing Record 26 of Set 3 | eskasem
# City not found. Skipping...
# Processing Record 27 of Set 3 | kailua
# Processing Record 28 of Set 3 | yar-sale
# Processing Record 29 of Set 3 | assiniboia
# Processing Record 30 of Set 3 | churapcha
# Processing Record 31 of Set 3 | varhaug
# Processing Record 32 of Set 3 | azul
# Processing Record 33 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 3 | amahai
# Processing Record 35 of Set 3 | bilma
# Processing Record 36 of Set 3 | cockburn town
# Processing Record 37 of Set 3 | linhares
# Processing Record 38 of Set 3 | yellowknife
# Processing Record 39 of Set 3 | boali
# Processing Record 40 of Set 3 | stokmarknes
# Processing Record 41 of Set 3 | jacareacanga
# Processing Record 42 of Set 3 | dutse
# Processing Record 43 of Set 3 | makung
# City not found. Skipping...
# Processing Record 44 of Set 3 | kungurtug
# Processing Record 45 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 47 of Set 3 | qeshm
# Processing Record 48 of Set 3 | xining
# Processing Record 49 of Set 3 | isla vista
# Processing Record 50 of Set 3 | falmouth
# Processing Record 1 of Set 4 | jalu
# Processing Record 2 of Set 4 | port lincoln
# Processing Record 3 of Set 4 | ostrovnoy
# Processing Record 4 of Set 4 | praia da vitoria
# Processing Record 5 of Set 4 | sur
# Processing Record 6 of Set 4 | north bend
# Processing Record 7 of Set 4 | korla
# Processing Record 8 of Set 4 | yakeshi
# Processing Record 9 of Set 4 | iracoubo
# Processing Record 10 of Set 4 | maceio
# Processing Record 11 of Set 4 | provideniya
# Processing Record 12 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 4 | sao filipe
# Processing Record 14 of Set 4 | sun prairie
# Processing Record 15 of Set 4 | norman wells
# Processing Record 16 of Set 4 | hobart
# Processing Record 17 of Set 4 | panaba
# Processing Record 18 of Set 4 | fos-sur-mer
# Processing Record 19 of Set 4 | padang
# Processing Record 20 of Set 4 | tornio
# Processing Record 21 of Set 4 | dinsor
# City not found. Skipping...
# Processing Record 22 of Set 4 | bolshaya glushitsa
# Processing Record 23 of Set 4 | bonavista
# Processing Record 24 of Set 4 | atasu
# Processing Record 25 of Set 4 | tonj
# Processing Record 26 of Set 4 | hithadhoo
# Processing Record 27 of Set 4 | lasa
# Processing Record 28 of Set 4 | si sa ket
# Processing Record 29 of Set 4 | torbay
# Processing Record 30 of Set 4 | lompoc
# Processing Record 31 of Set 4 | lae
# Processing Record 32 of Set 4 | aripuana
# Processing Record 33 of Set 4 | ouahigouya
# Processing Record 34 of Set 4 | meadow lake
# Processing Record 35 of Set 4 | tasiilaq
# Processing Record 36 of Set 4 | bredasdorp
# Processing Record 37 of Set 4 | touros
# Processing Record 38 of Set 4 | kachikau
# City not found. Skipping...
# Processing Record 39 of Set 4 | neepawa
# Processing Record 40 of Set 4 | aguimes
# Processing Record 41 of Set 4 | bengkulu
# Processing Record 42 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 4 | byron bay
# Processing Record 44 of Set 4 | boa vista
# Processing Record 45 of Set 4 | alofi
# Processing Record 46 of Set 4 | wanning
# Processing Record 47 of Set 4 | teseney
# Processing Record 48 of Set 4 | nyurba
# Processing Record 49 of Set 4 | esperance
# Processing Record 50 of Set 4 | tura
# Processing Record 1 of Set 5 | saint-augustin
# Processing Record 2 of Set 5 | berlevag
# Processing Record 3 of Set 5 | port keats
# Processing Record 4 of Set 5 | tomatlan
# Processing Record 5 of Set 5 | gusinoye ozero
# Processing Record 6 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 5 | khatanga
# Processing Record 8 of Set 5 | tazovskiy
# Processing Record 9 of Set 5 | jamestown
# Processing Record 10 of Set 5 | kargopol
# Processing Record 11 of Set 5 | port blair
# Processing Record 12 of Set 5 | thompson
# Processing Record 13 of Set 5 | stettler
# Processing Record 14 of Set 5 | havoysund
# Processing Record 15 of Set 5 | ulaangom
# Processing Record 16 of Set 5 | gobabis
# Processing Record 17 of Set 5 | forestville
# Processing Record 18 of Set 5 | shenjiamen
# Processing Record 19 of Set 5 | pevek
# Processing Record 20 of Set 5 | pacific grove
# Processing Record 21 of Set 5 | saint-philippe
# Processing Record 22 of Set 5 | hami
# Processing Record 23 of Set 5 | skjervoy
# Processing Record 24 of Set 5 | okhotsk
# Processing Record 25 of Set 5 | cayenne
# Processing Record 26 of Set 5 | beyneu
# Processing Record 27 of Set 5 | balabac
# Processing Record 28 of Set 5 | etchoropo
# Processing Record 29 of Set 5 | qandala
# Processing Record 30 of Set 5 | vardo
# Processing Record 31 of Set 5 | guerrero negro
# Processing Record 32 of Set 5 | ouallam
# Processing Record 33 of Set 5 | camacha
# Processing Record 34 of Set 5 | marzuq
# Processing Record 35 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 5 | truro
# Processing Record 37 of Set 5 | maniitsoq
# Processing Record 38 of Set 5 | itapecerica da serra
# Processing Record 39 of Set 5 | orzu
# Processing Record 40 of Set 5 | thurso
# Processing Record 41 of Set 5 | kieta
# Processing Record 42 of Set 5 | college
# Processing Record 43 of Set 5 | armidale
# Processing Record 44 of Set 5 | yeniseysk
# Processing Record 45 of Set 5 | biskamzha
# Processing Record 46 of Set 5 | aloleng
# Processing Record 47 of Set 5 | marawi
# Processing Record 48 of Set 5 | mersin
# Processing Record 49 of Set 5 | energetik
# Processing Record 50 of Set 5 | waynesboro
# Processing Record 1 of Set 6 | acarau
# Processing Record 2 of Set 6 | tshikapa
# Processing Record 3 of Set 6 | massakory
# Processing Record 4 of Set 6 | dianopolis
# City not found. Skipping...
# Processing Record 5 of Set 6 | dodge city
# Processing Record 6 of Set 6 | huilong
# Processing Record 7 of Set 6 | praya
# Processing Record 8 of Set 6 | lavrentiya
# Processing Record 9 of Set 6 | manzhouli
# Processing Record 10 of Set 6 | clyde river
# Processing Record 11 of Set 6 | sedona
# Processing Record 12 of Set 6 | coahuayana
# Processing Record 13 of Set 6 | kununurra
# Processing Record 14 of Set 6 | anadyr
# Processing Record 15 of Set 6 | abu dhabi
# Processing Record 16 of Set 6 | vostok
# Processing Record 17 of Set 6 | airai
# Processing Record 18 of Set 6 | tefe
# Processing Record 19 of Set 6 | kamariotissa
# Processing Record 20 of Set 6 | eureka
# Processing Record 21 of Set 6 | nova venecia
# Processing Record 22 of Set 6 | iqaluit
# Processing Record 23 of Set 6 | kaitangata
# Processing Record 24 of Set 6 | baft
# Processing Record 25 of Set 6 | mount pleasant
# Processing Record 26 of Set 6 | jumla
# Processing Record 27 of Set 6 | grand gaube
# Processing Record 28 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 6 | romitan
# Processing Record 30 of Set 6 | mozarlandia
# Processing Record 31 of Set 6 | ngunguru
# Processing Record 32 of Set 6 | loknya
# Processing Record 33 of Set 6 | severnyy
# Processing Record 34 of Set 6 | polyarnyy
# Processing Record 35 of Set 6 | teguise
# Processing Record 36 of Set 6 | danilov
# Processing Record 37 of Set 6 | quatre cocos
# Processing Record 38 of Set 6 | barra do garcas
# Processing Record 39 of Set 6 | tuatapere
# Processing Record 40 of Set 6 | amazar
# Processing Record 41 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 6 | chokurdakh
# Processing Record 43 of Set 6 | cah ab
# City not found. Skipping...
# Processing Record 44 of Set 6 | katete
# Processing Record 45 of Set 6 | south river
# Processing Record 46 of Set 6 | san lawrenz
# Processing Record 47 of Set 6 | mutsu
# Processing Record 48 of Set 6 | carnarvon
# Processing Record 49 of Set 6 | usinsk
# Processing Record 50 of Set 6 | sabancuy
# Processing Record 1 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 7 | narsaq
# Processing Record 3 of Set 7 | parfenyevo
# Processing Record 4 of Set 7 | kruisfontein
# Processing Record 5 of Set 7 | san policarpo
# Processing Record 6 of Set 7 | baykit
# Processing Record 7 of Set 7 | valcourt
# Processing Record 8 of Set 7 | coquimbo
# Processing Record 9 of Set 7 | nanortalik
# Processing Record 10 of Set 7 | richards bay
# Processing Record 11 of Set 7 | vanderhoof
# Processing Record 12 of Set 7 | raudeberg
# Processing Record 13 of Set 7 | tutoia
# Processing Record 14 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 7 | sola
# Processing Record 16 of Set 7 | kala nera
# Processing Record 17 of Set 7 | iwanai
# Processing Record 18 of Set 7 | numan
# Processing Record 19 of Set 7 | tanga
# Processing Record 20 of Set 7 | luderitz
# Processing Record 21 of Set 7 | la tuque
# Processing Record 22 of Set 7 | rorvik
# Processing Record 23 of Set 7 | macaparana
# Processing Record 24 of Set 7 | parkes
# Processing Record 25 of Set 7 | ixtapa
# Processing Record 26 of Set 7 | san andres
# Processing Record 27 of Set 7 | souillac
# Processing Record 28 of Set 7 | geraldton
# Processing Record 29 of Set 7 | tromso
# Processing Record 30 of Set 7 | saquena
# Processing Record 31 of Set 7 | mahibadhoo
# Processing Record 32 of Set 7 | caravelas
# Processing Record 33 of Set 7 | paamiut
# Processing Record 34 of Set 7 | lorengau
# Processing Record 35 of Set 7 | faya
# Processing Record 36 of Set 7 | faanui
# Processing Record 37 of Set 7 | port hardy
# Processing Record 38 of Set 7 | port elizabeth
# Processing Record 39 of Set 7 | mount isa
# Processing Record 40 of Set 7 | constitucion
# Processing Record 41 of Set 7 | la ronge
# Processing Record 42 of Set 7 | bereda
# Processing Record 43 of Set 7 | brae
# Processing Record 44 of Set 7 | haines junction
# Processing Record 45 of Set 7 | kattivakkam
# Processing Record 46 of Set 7 | kahului
# Processing Record 47 of Set 7 | la paz
# Processing Record 48 of Set 7 | akyab
# Processing Record 49 of Set 7 | tarakan
# Processing Record 50 of Set 7 | roald
# Processing Record 1 of Set 8 | salalah
# Processing Record 2 of Set 8 | la asuncion
# Processing Record 3 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 4 of Set 8 | sakakah
# Processing Record 5 of Set 8 | pirae
# Processing Record 6 of Set 8 | makakilo city
# Processing Record 7 of Set 8 | buenavista
# Processing Record 8 of Set 8 | bembereke
# Processing Record 9 of Set 8 | sale
# Processing Record 10 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 11 of Set 8 | zhigansk
# Processing Record 12 of Set 8 | lazurne
# Processing Record 13 of Set 8 | zhurivka
# Processing Record 14 of Set 8 | dubti
# Processing Record 15 of Set 8 | shebunino
# Processing Record 16 of Set 8 | ujiie
# Processing Record 17 of Set 8 | paredon
# Processing Record 18 of Set 8 | alice springs
# Processing Record 19 of Set 8 | goldsboro
# Processing Record 20 of Set 8 | sabha
# Processing Record 21 of Set 8 | opunake
# Processing Record 22 of Set 8 | saldanha
# Processing Record 23 of Set 8 | upata
# Processing Record 24 of Set 8 | krasnoselkup
# Processing Record 25 of Set 8 | longyearbyen
# Processing Record 26 of Set 8 | houma
# Processing Record 27 of Set 8 | yerbogachen
# Processing Record 28 of Set 8 | umm kaddadah
# Processing Record 29 of Set 8 | harper
# Processing Record 30 of Set 8 | port moresby
# Processing Record 31 of Set 8 | ponta do sol
# Processing Record 32 of Set 8 | kudahuvadhoo
# Processing Record 33 of Set 8 | garowe
# Processing Record 34 of Set 8 | elk city
# Processing Record 35 of Set 8 | husavik
# Processing Record 36 of Set 8 | dangtu
# Processing Record 37 of Set 8 | hinche
# Processing Record 38 of Set 8 | dogondoutchi
# Processing Record 39 of Set 8 | basco
# Processing Record 40 of Set 8 | flinders
# Processing Record 41 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 42 of Set 8 | whitehorse
# Processing Record 43 of Set 8 | talisayan
# Processing Record 44 of Set 8 | saurimo
# Processing Record 45 of Set 8 | deputatskiy
# Processing Record 46 of Set 8 | belyy yar
# Processing Record 47 of Set 8 | vila franca do campo
# Processing Record 48 of Set 8 | the valley
# Processing Record 49 of Set 8 | san martin
# Processing Record 50 of Set 8 | arvika
# Processing Record 1 of Set 9 | ankang
# Processing Record 2 of Set 9 | jackson
# Processing Record 3 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 9 | riyadh
# Processing Record 5 of Set 9 | reconquista
# Processing Record 6 of Set 9 | fallon
# Processing Record 7 of Set 9 | komsomolskiy
# Processing Record 8 of Set 9 | flums
# Processing Record 9 of Set 9 | yuryevets
# Processing Record 10 of Set 9 | kidal
# Processing Record 11 of Set 9 | upernavik
# Processing Record 12 of Set 9 | mweka
# Processing Record 13 of Set 9 | tommot
# Processing Record 14 of Set 9 | kabinda
# Processing Record 15 of Set 9 | novo aripuana
# Processing Record 16 of Set 9 | shelburne
# Processing Record 17 of Set 9 | lubango
# Processing Record 18 of Set 9 | san pedro
# Processing Record 19 of Set 9 | antsohihy
# Processing Record 20 of Set 9 | teahupoo
# Processing Record 21 of Set 9 | saposoa
# Processing Record 22 of Set 9 | sobolevo
# Processing Record 23 of Set 9 | cap malheureux
# Processing Record 24 of Set 9 | skala
# Processing Record 25 of Set 9 | hasaki
# Processing Record 26 of Set 9 | udachnyy
# Processing Record 27 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 9 | vila
# Processing Record 30 of Set 9 | pemba
# Processing Record 31 of Set 9 | poum
# Processing Record 32 of Set 9 | kodiak
# Processing Record 33 of Set 9 | waipawa
# Processing Record 34 of Set 9 | caraquet
# Processing Record 35 of Set 9 | peniche
# Processing Record 36 of Set 9 | west fargo
# Processing Record 37 of Set 9 | qaqortoq
# Processing Record 38 of Set 9 | keffi
# Processing Record 39 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 40 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 41 of Set 9 | bodden town
# Processing Record 42 of Set 9 | ponta delgada
# Processing Record 43 of Set 9 | alenquer
# Processing Record 44 of Set 9 | yeppoon
# Processing Record 45 of Set 9 | manokwari
# Processing Record 46 of Set 9 | noumea
# Processing Record 47 of Set 9 | naryan-mar
# Processing Record 48 of Set 9 | paracuru
# Processing Record 49 of Set 9 | lakes entrance
# Processing Record 50 of Set 9 | batemans bay
# Processing Record 1 of Set 10 | fomboni
# Processing Record 2 of Set 10 | pullman
# Processing Record 3 of Set 10 | otavi
# Processing Record 4 of Set 10 | seoul
# Processing Record 5 of Set 10 | porbandar
# Processing Record 6 of Set 10 | tautira
# Processing Record 7 of Set 10 | novoomskiy
# Processing Record 8 of Set 10 | corning
# Processing Record 9 of Set 10 | fairbanks
# Processing Record 10 of Set 10 | dukat
# Processing Record 11 of Set 10 | gondal
# Processing Record 12 of Set 10 | sao joao da barra
# Processing Record 13 of Set 10 | malayal
# Processing Record 14 of Set 10 | nikolayevka
# Processing Record 15 of Set 10 | ballina
# Processing Record 16 of Set 10 | todos santos
# Processing Record 17 of Set 10 | pisco
# Processing Record 18 of Set 10 | katangli
# Processing Record 19 of Set 10 | ketchikan
# Processing Record 20 of Set 10 | gamba
# Processing Record 21 of Set 10 | halifax
# Processing Record 22 of Set 10 | vanimo
# Processing Record 23 of Set 10 | margate
# Processing Record 24 of Set 10 | lagoa
# Processing Record 25 of Set 10 | nicoya
# Processing Record 26 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 10 | sakaraha
# Processing Record 28 of Set 10 | djambala
# Processing Record 29 of Set 10 | celestun
# Processing Record 30 of Set 10 | boddam
# Processing Record 31 of Set 10 | issoudun
# Processing Record 32 of Set 10 | evenskjaer
# City not found. Skipping...
# Processing Record 33 of Set 10 | mudgee
# Processing Record 34 of Set 10 | dzitbalche
# Processing Record 35 of Set 10 | braslav
# City not found. Skipping...
# Processing Record 36 of Set 10 | hermiston
# Processing Record 37 of Set 10 | hit
# Processing Record 38 of Set 10 | khor
# Processing Record 39 of Set 10 | savannah bight
# Processing Record 40 of Set 10 | plettenberg bay
# Processing Record 41 of Set 10 | hvammstangi
# City not found. Skipping...
# Processing Record 42 of Set 10 | labuhan
# Processing Record 43 of Set 10 | puerto cortes
# City not found. Skipping...
# Processing Record 44 of Set 10 | dubrovka
# Processing Record 45 of Set 10 | klaksvik
# Processing Record 46 of Set 10 | buin
# Processing Record 47 of Set 10 | antofagasta
# Processing Record 48 of Set 10 | dandong
# Processing Record 49 of Set 10 | sioux lookout
# Processing Record 50 of Set 10 | nioro
# Processing Record 1 of Set 11 | avera
# Processing Record 2 of Set 11 | mecca
# Processing Record 3 of Set 11 | prince rupert
# Processing Record 4 of Set 11 | garden city
# Processing Record 5 of Set 11 | freeport
# Processing Record 6 of Set 11 | kaihua
# Processing Record 7 of Set 11 | xudat
# Processing Record 8 of Set 11 | shimoda
# Processing Record 9 of Set 11 | changji
# Processing Record 10 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 11 of Set 11 | hamilton
# Processing Record 12 of Set 11 | tahoua
# Processing Record 13 of Set 11 | presidente olegario
# Processing Record 14 of Set 11 | tocopilla
# Processing Record 15 of Set 11 | westport
# Processing Record 16 of Set 11 | dilla
# Processing Record 17 of Set 11 | bara
# Processing Record 18 of Set 11 | banjar
# Processing Record 19 of Set 11 | guilin
# Processing Record 20 of Set 11 | trapani
# Processing Record 21 of Set 11 | bethanien
# Processing Record 22 of Set 11 | wagar
# Processing Record 23 of Set 11 | okha
# Processing Record 24 of Set 11 | koumac
# Processing Record 25 of Set 11 | neiafu
# Processing Record 26 of Set 11 | rassvet
# Processing Record 27 of Set 11 | chikwawa
# Processing Record 28 of Set 11 | benavente
# Processing Record 29 of Set 11 | mandalgarh
# Processing Record 30 of Set 11 | menongue
# Processing Record 31 of Set 11 | tamandare
# Processing Record 32 of Set 11 | mahon
# Processing Record 33 of Set 11 | cornwall
# Processing Record 34 of Set 11 | severodvinsk
# Processing Record 35 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 11 | tazmalt
# Processing Record 37 of Set 11 | papetoai
# Processing Record 38 of Set 11 | samarai
# Processing Record 39 of Set 11 | saint george
# Processing Record 40 of Set 11 | japura
# Processing Record 41 of Set 11 | isangel
# Processing Record 42 of Set 11 | joshimath
# Processing Record 43 of Set 11 | hearst
# Processing Record 44 of Set 11 | sovetskaya
# Processing Record 45 of Set 11 | guanare
# Processing Record 46 of Set 11 | karaton
# Processing Record 47 of Set 11 | emerald
# Processing Record 48 of Set 11 | krasnaya gorbatka
# Processing Record 49 of Set 11 | shiyan
# Processing Record 50 of Set 11 | portland
# Processing Record 1 of Set 12 | nishihara
# Processing Record 2 of Set 12 | meulaboh
# Processing Record 3 of Set 12 | maldonado
# Processing Record 4 of Set 12 | nanakuli
# Processing Record 5 of Set 12 | khani
# Processing Record 6 of Set 12 | valle de allende
# Processing Record 7 of Set 12 | bonga
# Processing Record 8 of Set 12 | karwar
# Processing Record 9 of Set 12 | kashary
# Processing Record 10 of Set 12 | kisangani
# Processing Record 11 of Set 12 | pochutla
# Processing Record 12 of Set 12 | krasnyye baki
# Processing Record 13 of Set 12 | uvarovo
# Processing Record 14 of Set 12 | teknaf
# Processing Record 15 of Set 12 | bulgan
# Processing Record 16 of Set 12 | luanda
# Processing Record 17 of Set 12 | fort nelson
# Processing Record 18 of Set 12 | hambantota
# Processing Record 19 of Set 12 | takoradi
# Processing Record 20 of Set 12 | ola
# Processing Record 21 of Set 12 | kolokani
# Processing Record 22 of Set 12 | forbes
# Processing Record 23 of Set 12 | sheridan
# Processing Record 24 of Set 12 | ocala
# Processing Record 25 of Set 12 | atherton
# Processing Record 26 of Set 12 | namibe
# Processing Record 27 of Set 12 | bahar
# Processing Record 28 of Set 12 | monrovia
# Processing Record 29 of Set 12 | obihiro
# Processing Record 30 of Set 12 | williams lake
# Processing Record 31 of Set 12 | san patricio
# Processing Record 32 of Set 12 | cidreira
# Processing Record 33 of Set 12 | olinda
# Processing Record 34 of Set 12 | santa ana
# Processing Record 35 of Set 12 | jambi
# Processing Record 36 of Set 12 | awjilah
# Processing Record 37 of Set 12 | ratnagiri
# Processing Record 38 of Set 12 | tarko-sale
# Processing Record 39 of Set 12 | miguel alves
# Processing Record 40 of Set 12 | szendro
# Processing Record 41 of Set 12 | kolomyya
# Processing Record 42 of Set 12 | paita
# Processing Record 43 of Set 12 | tezu
# Processing Record 44 of Set 12 | zambezi
# Processing Record 45 of Set 12 | shubarshi
# Processing Record 46 of Set 12 | mwinilunga
# Processing Record 47 of Set 12 | dunmore east
# Processing Record 48 of Set 12 | creel
# Processing Record 49 of Set 12 | paramonga
# Processing Record 50 of Set 12 | san luis
# Processing Record 1 of Set 13 | onega
# Processing Record 2 of Set 13 | lola
# Processing Record 3 of Set 13 | magburaka
# Processing Record 4 of Set 13 | san jose
# Processing Record 5 of Set 13 | ravar
# Processing Record 6 of Set 13 | porto novo
# Processing Record 7 of Set 13 | sosnovka
# Processing Record 8 of Set 13 | mount gambier
# Processing Record 9 of Set 13 | makokou
# Processing Record 10 of Set 13 | nome
# Processing Record 11 of Set 13 | namanga
# Processing Record 12 of Set 13 | acajutla
# Processing Record 13 of Set 13 | ozernovskiy
# Processing Record 14 of Set 13 | miandrivazo
# Processing Record 15 of Set 13 | alekseyevsk
# Processing Record 16 of Set 13 | huarmey
# Processing Record 17 of Set 13 | catalina
# Processing Record 18 of Set 13 | krasnyy chikoy
# Processing Record 19 of Set 13 | umm lajj
# Processing Record 20 of Set 13 | navalmoral de la mata
# Processing Record 21 of Set 13 | north marysville
# City not found. Skipping...
# Processing Record 22 of Set 13 | puerto baquerizo moreno
# Processing Record 23 of Set 13 | bogorodskoye
# Processing Record 24 of Set 13 | razdolnoye
# Processing Record 25 of Set 13 | invermere
# Processing Record 26 of Set 13 | slupsk
# Processing Record 27 of Set 13 | huntingdon
# Processing Record 28 of Set 13 | rio grande
# Processing Record 29 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 13 | lajosmizse
# Processing Record 31 of Set 13 | namatanai
# Processing Record 32 of Set 13 | atlantis
# Processing Record 33 of Set 13 | uttaradit
# Processing Record 34 of Set 13 | angoche
# Processing Record 35 of Set 13 | buala
# Processing Record 36 of Set 13 | kavieng
# Processing Record 37 of Set 13 | palmer
# Processing Record 38 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 39 of Set 13 | weiser
# Processing Record 40 of Set 13 | nampula
# Processing Record 41 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 42 of Set 13 | puerto del rosario
# Processing Record 43 of Set 13 | sahuaripa
# Processing Record 44 of Set 13 | ugoofaaru
# Processing Record 45 of Set 13 | ayan
# Processing Record 46 of Set 13 | liuzhou
# Processing Record 47 of Set 13 | sao geraldo do araguaia
# Processing Record 48 of Set 13 | payakumbuh
# Processing Record 49 of Set 13 | urumqi
# Processing Record 50 of Set 13 | illapel
# Processing Record 1 of Set 14 | canchungo
# Processing Record 2 of Set 14 | beckley
# Processing Record 3 of Set 14 | aykhal
# Processing Record 4 of Set 14 | barranca
# Processing Record 5 of Set 14 | los llanos de aridane
# Processing Record 6 of Set 14 | shorapur
# Processing Record 7 of Set 14 | zalari
# Processing Record 8 of Set 14 | pingzhuang
# Processing Record 9 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 14 | cabo san lucas
# Processing Record 11 of Set 14 | nuevitas
# Processing Record 12 of Set 14 | mehamn
# Processing Record 13 of Set 14 | aden
# Processing Record 14 of Set 14 | cabedelo
# Processing Record 15 of Set 14 | foix
# Processing Record 16 of Set 14 | olafsvik
# Processing Record 17 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 18 of Set 14 | kaka
# Processing Record 19 of Set 14 | weymouth
# Processing Record 20 of Set 14 | asfi
# Processing Record 21 of Set 14 | port hedland
# Processing Record 22 of Set 14 | maracas
# Processing Record 23 of Set 14 | duma
# Processing Record 24 of Set 14 | perth
# Processing Record 25 of Set 14 | anito
# Processing Record 26 of Set 14 | najran
# Processing Record 27 of Set 14 | uk
# City not found. Skipping...
# Processing Record 28 of Set 14 | spitsevka
# Processing Record 29 of Set 14 | nouakchott
# Processing Record 30 of Set 14 | agva
# City not found. Skipping...
# Processing Record 31 of Set 14 | san carlos
# Processing Record 32 of Set 14 | chekhov
# Processing Record 33 of Set 14 | taoudenni
# Processing Record 34 of Set 14 | puebloviejo
# Processing Record 35 of Set 14 | ulladulla
# Processing Record 36 of Set 14 | alice town
# Processing Record 37 of Set 14 | ahuimanu
# Processing Record 38 of Set 14 | dubai
# Processing Record 39 of Set 14 | marienburg
# Processing Record 40 of Set 14 | anaco
# Processing Record 41 of Set 14 | kitob
# Processing Record 42 of Set 14 | tianpeng
# Processing Record 43 of Set 14 | sayville
# Processing Record 44 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 14 | deyang
# Processing Record 46 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 14 | soverato
# Processing Record 48 of Set 14 | kupang
# Processing Record 49 of Set 14 | jining
# Processing Record 50 of Set 14 | burnie
# Processing Record 1 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 4 of Set 15 | fernley
# Processing Record 5 of Set 15 | daru
# Processing Record 6 of Set 15 | mayna
# Processing Record 7 of Set 15 | winton
# Processing Record 8 of Set 15 | priiskovyy
# Processing Record 9 of Set 15 | andujar
# Processing Record 10 of Set 15 | asilah
# Processing Record 11 of Set 15 | mao
# Processing Record 12 of Set 15 | karmana
# City not found. Skipping...
# Processing Record 13 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 15 | morehead
# Processing Record 15 of Set 15 | iida
# Processing Record 16 of Set 15 | half moon bay
# Processing Record 17 of Set 15 | beloha
# Processing Record 18 of Set 15 | tselinnoye
# Processing Record 19 of Set 15 | manjeshwar
# Processing Record 20 of Set 15 | snellville
# Processing Record 21 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 15 | andenes
# Processing Record 23 of Set 15 | dwarka
# Processing Record 24 of Set 15 | becerril
# Processing Record 25 of Set 15 | novoagansk
# Processing Record 26 of Set 15 | chake chake
# Processing Record 27 of Set 15 | laguna
# Processing Record 28 of Set 15 | kenai
# Processing Record 29 of Set 15 | anchorage
# Processing Record 30 of Set 15 | siniscola
# Processing Record 31 of Set 15 | keflavik
# Processing Record 32 of Set 15 | kenitra
# Processing Record 33 of Set 15 | elizabeth city
# Processing Record 34 of Set 15 | seymchan
# Processing Record 35 of Set 15 | sol-iletsk
# Processing Record 36 of Set 15 | lugo
# Processing Record 37 of Set 15 | mayo
# Processing Record 38 of Set 15 | raga
# Processing Record 39 of Set 15 | marsa matruh
# Processing Record 40 of Set 15 | mantua
# Processing Record 41 of Set 15 | colomi
# Processing Record 42 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 43 of Set 15 | ruteng
# Processing Record 44 of Set 15 | plerin
# Processing Record 45 of Set 15 | humaita
# Processing Record 46 of Set 15 | broome
# Processing Record 47 of Set 15 | tecoanapa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Dikson  73.5069   80.5464      5.79        89         100
# 1         Ca Mau   9.1769  105.1500     75.45        91          99
# 2       Katsuura  35.1333  140.3000     46.51        68           0
# 3      Mahebourg -20.4081   57.7000     76.24        88          40
# 4           Lebu -37.6167  -73.6500     60.15        75          22
# 5  San Cristobal   7.7669  -72.2250     68.18        91          69
# 6         Albany  42.6001  -73.9662     40.75        52           3
# 7       Karratha -20.7377  116.8463     80.51        47          74
# 8        Rikitea -23.1203 -134.9692     76.59        78          18
# 9          Tabou   4.4230   -7.3528     80.08        83          38
#
#    Wind Speed Country                 Date Weather description
# 0       10.02      RU  2021-11-24 20:35:15     overcast clouds
# 1        7.07      VN  2021-11-24 20:34:34     overcast clouds
# 2        9.66      JP  2021-11-24 20:35:16           clear sky
# 3        4.61      MU  2021-11-24 20:35:16    scattered clouds
# 4        8.57      CL  2021-11-24 20:35:16          few clouds
# 5        2.59      VE  2021-11-24 20:35:17       broken clouds
# 6        3.51      US  2021-11-24 20:35:17           clear sky
# 7        9.66      AU  2021-11-24 20:35:18       broken clouds
# 8       15.12      PF  2021-11-24 20:35:18          few clouds
# 9        6.87      CI  2021-11-24 20:35:18    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather description"]
city_data_df_new = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0         Dikson      RU  2021-11-24 20:35:15  73.5069   80.5464      5.79
# 1         Ca Mau      VN  2021-11-24 20:34:34   9.1769  105.1500     75.45
# 2       Katsuura      JP  2021-11-24 20:35:16  35.1333  140.3000     46.51
# 3      Mahebourg      MU  2021-11-24 20:35:16 -20.4081   57.7000     76.24
# 4           Lebu      CL  2021-11-24 20:35:16 -37.6167  -73.6500     60.15
# 5  San Cristobal      VE  2021-11-24 20:35:17   7.7669  -72.2250     68.18
# 6         Albany      US  2021-11-24 20:35:17  42.6001  -73.9662     40.75
# 7       Karratha      AU  2021-11-24 20:35:18 -20.7377  116.8463     80.51
# 8        Rikitea      PF  2021-11-24 20:35:18 -23.1203 -134.9692     76.59
# 9          Tabou      CI  2021-11-24 20:35:18   4.4230   -7.3528     80.08
#
#    Humidity  Cloudiness  Wind Speed Weather description
# 0        89         100       10.02     overcast clouds
# 1        91          99        7.07     overcast clouds
# 2        68           0        9.66           clear sky
# 3        88          40        4.61    scattered clouds
# 4        75          22        8.57          few clouds
# 5        91          69        2.59       broken clouds
# 6        52           3        3.51           clear sky
# 7        47          74        9.66       broken clouds
# 8        78          18       15.12          few clouds
# 9        83          38        6.87    scattered clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df_new.to_csv(output_data_file, index_label="City_ID")
